# %% [markdown]
# # Standardization Utility

# %% [markdown]
# ### Overview
# This is a semi-automated process that can help in standardizing similar values of conformed attributes (dimensions) pulled from two different sources. It works under the following circumstances:
# - Attribute values come from two sources.
# - Attribute values are mainly lists.
#
# ### Process
# - Loading and preprocessing
# - Matching
#     - the values are split on punctuation (`,`, `-`, `&`) into the individial names which are then exploded and used for joining the sources.
#     - then values that contain >= 2 common individual names are considered as valid matches.
#     - union of the two values are created from the valid matches.
#     - matches are exported as a dictionary mapping the value and the union for each source.
# - Other unmatched values are then outlined for further review.
#
# ### Notes
# - This is a semi automatic utility, so manual review is necessary in every stage of th process to point out minor nuances that prevent values from being matched (.e.g plural vs singular forms, `ing` forms)

# %%
import requests
import pandas as pd
from dz_jobs_aggregator.utils import french_titlecase
import re

pd.set_option("max_colwidth", 600)
LANG = "fr"

# %%
# ---- Emploi Partner Transformations ----
emploi_partner_dimenion_url = "https://api-v4.emploipartner.com/api/params_functions?&pagination=false"
response = requests.get(emploi_partner_dimenion_url, headers={"Accept-Language": LANG})
label_key = "name"
ep_df = pd.DataFrame(response.json()["hydra:member"])[[label_key]].drop_duplicates()

# Replace any slashes with commas.
ep_df[label_key] = ep_df[label_key].apply(lambda x: re.sub(r"\s*/\s*", ", ", x))

# Apply custom titlecase
ep_df[label_key] = ep_df[label_key].apply(french_titlecase)

ep_df = ep_df.rename(columns={label_key: "emploi_partner"})

# ---- Emploitic Transformations ----
emploitic_dimension_url = f"https://emploitic.com/api/v4/lists/metiers?&lang={LANG}&per_page=30"
response = requests.get(emploitic_dimension_url)
em_label_key = "label"
em_df = pd.DataFrame(response.json()["collection"])[[em_label_key]].drop_duplicates()

# Apply custom titlecase
em_df[em_label_key] = em_df[em_label_key].apply(french_titlecase)
em_df = em_df.rename(columns={em_label_key: "emploitic"})

# ---- Merge Both Data Sources ----
merged = pd.merge(ep_df, em_df, left_on="emploi_partner", right_on="emploitic", how="outer")
# merged.to_json("merged_functions.json", orient="records", force_ascii=False)
merged
# Out:
#                                  emploi_partner  \
# 0   Accueil, Administration - Services Généraux
# 1                                           NaN
# 2                                           NaN
# 3                               Armées, Défense
# 4                                           NaN
# ..                                          ...
# 61           Tourisme, Hôtellerie, Restauration
# 62      Transport, Achat, Logistique, Emballage
# 63                                          NaN
# 64         Télécommunications, Systèmes, Réseau
# 65                                          NaN
#
#                                             emploitic
# 0                                                 NaN
# 1   Administration, Finance, Comptabilité & Juridique
# 2                     Administration, Moyens Généraux
# 3                                                 NaN
# 4                             Assistanat, Secrétariat
# ..                                                ...
# 61                                                NaN
# 62                                                NaN
# 63                         Télécommunication, Réseaux
# 64                                                NaN
# 65                       Vente, Télévente, Assistanat
#
# [66 rows x 2 columns]

# %%
# split on (',', '-' or '&')
split_pattern = "\s*,\s*|\s*-\s*|\s+&\s*|\s*&\s+"
ep_df["emploi_partner_name"] = ep_df["emploi_partner"].apply(
    lambda x: re.split(split_pattern, x)
)
ep_df["emploi_partner_set"] = ep_df["emploi_partner_name"].copy().apply(lambda x: set(x))

em_df["emploitic_name"] = em_df["emploitic"].apply(
    lambda x: re.split(split_pattern, x)
)
em_df["emploitic_set"] = em_df["emploitic_name"].copy().apply(lambda x: set(x))

ep_df_expld = ep_df.explode("emploi_partner_name")
em_df_expld = em_df.explode("emploitic_name")
merged_expld = pd.merge(
    ep_df_expld,
    em_df_expld,
    left_on="emploi_partner_name",
    right_on="emploitic_name",
)
set_union = lambda row: row["emploi_partner_set"] | row["emploitic_set"]
set_to_str = lambda row: ', '.join(sorted(row["union"]))
merged_expld["union"] = merged_expld.apply(set_union, axis="columns")
merged_expld["union_str"] = merged_expld.apply(set_to_str, axis="columns")
merged_expld
# Out:
#                                                           emploi_partner  \
# 0                            Accueil, Administration - Services Généraux
# 1                            Accueil, Administration - Services Généraux
# 2                                          Création, Culture, Spectacles
# 3                                          Création, Culture, Spectacles
# 4                                          Commerce, Distribution, Vente
# 5                                                      Juridique, Fiscal
# 6                                                      Juridique, Fiscal
# 7                                                      Juridique, Fiscal
# 8                                Edition, Imprimerie, Presse, Traduction
# 9     Industrie, Electrique et Électrotechnique, Production, Maintenance
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 11    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 12    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 13                                      Audit, Gestion, Finances, Compta
# 14                          Immobilier, Architecture, Urbanisme, Paysage
# 15  Informatique, Systèmes d'Information, Analyse et Science des Données
# 16  Informatique, Systèmes d'Information, Analyse et Science des Données
# 17  Informatique, Systèmes d'Information, Analyse et Science des Données
# 18                                   Création, Design, Médias Numériques
# 19                                   Création, Design, Médias Numériques
# 20                                   Création, Design, Médias Numériques
# 21                                          Marketing, Communication, RP
# 22                                          Marketing, Communication, RP
# 23                                          Marketing, Communication, RP
# 24                                          Marketing, Communication, RP
# 25                                      Qualité, Sécurité, Environnement
# 26                                      Qualité, Sécurité, Environnement
# 27                                      Qualité, Sécurité, Environnement
# 28                                         Santé Hopital, Pharmaceutique
# 29                                    Tourisme, Hôtellerie, Restauration
# 30                                    Tourisme, Hôtellerie, Restauration
# 31                                    Tourisme, Hôtellerie, Restauration
# 32                               Transport, Achat, Logistique, Emballage
# 33                               Transport, Achat, Logistique, Emballage
# 34                               Transport, Achat, Logistique, Emballage
# 35                              Ingénierie, Bureau d'Études, Projet, R&D
# 36                              Ingénierie, Bureau d'Études, Projet, R&D
# 37                              Ingénierie, Bureau d'Études, Projet, R&D
# 38                              Ingénierie, Bureau d'Études, Projet, R&D
# 39                                      Métiers de l'Agriculture, Nature
# 40                                                                Autres
# 41                        Chauffeur, Agent d'Entretien, Agent Polyvalent
#
#          emploi_partner_name  \
# 0             Administration
# 1             Administration
# 2                   Création
# 3                   Création
# 4                      Vente
# 5                  Juridique
# 6                  Juridique
# 7                     Fiscal
# 8                 Traduction
# 9                  Industrie
# 10                 Industrie
# 11                Production
# 12               Maintenance
# 13                     Audit
# 14              Architecture
# 15              Informatique
# 16              Informatique
# 17    Systèmes d'Information
# 18                  Création
# 19                  Création
# 20                    Design
# 21                 Marketing
# 22                 Marketing
# 23             Communication
# 24             Communication
# 25                   Qualité
# 26                  Sécurité
# 27             Environnement
# 28            Pharmaceutique
# 29                  Tourisme
# 30                Hôtellerie
# 31              Restauration
# 32                 Transport
# 33                     Achat
# 34                Logistique
# 35                Ingénierie
# 36                Ingénierie
# 37                    Projet
# 38                       R&D
# 39  Métiers de l'Agriculture
# 40                    Autres
# 41                 Chauffeur
#
#                                                         emploi_partner_set  \
# 0                             {Accueil, Services Généraux, Administration}
# 1                             {Accueil, Services Généraux, Administration}
# 2                                          {Spectacles, Culture, Création}
# 3                                          {Spectacles, Culture, Création}
# 4                                          {Commerce, Distribution, Vente}
# 5                                                      {Juridique, Fiscal}
# 6                                                      {Juridique, Fiscal}
# 7                                                      {Juridique, Fiscal}
# 8                                {Presse, Traduction, Edition, Imprimerie}
# 9     {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 10    {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 11    {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 12    {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 13                                      {Compta, Audit, Finances, Gestion}
# 14                          {Urbanisme, Paysage, Architecture, Immobilier}
# 15  {Analyse et Science des Données, Systèmes d'Information, Informatique}
# 16  {Analyse et Science des Données, Systèmes d'Information, Informatique}
# 17  {Analyse et Science des Données, Systèmes d'Information, Informatique}
# 18                                   {Création, Design, Médias Numériques}
# 19                                   {Création, Design, Médias Numériques}
# 20                                   {Création, Design, Médias Numériques}
# 21                                          {RP, Marketing, Communication}
# 22                                          {RP, Marketing, Communication}
# 23                                          {RP, Marketing, Communication}
# 24                                          {RP, Marketing, Communication}
# 25                                      {Environnement, Sécurité, Qualité}
# 26                                      {Environnement, Sécurité, Qualité}
# 27                                      {Environnement, Sécurité, Qualité}
# 28                                         {Pharmaceutique, Santé Hopital}
# 29                                    {Restauration, Tourisme, Hôtellerie}
# 30                                    {Restauration, Tourisme, Hôtellerie}
# 31                                    {Restauration, Tourisme, Hôtellerie}
# 32                               {Logistique, Transport, Achat, Emballage}
# 33                               {Logistique, Transport, Achat, Emballage}
# 34                               {Logistique, Transport, Achat, Emballage}
# 35                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 36                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 37                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 38                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 39                                      {Métiers de l'Agriculture, Nature}
# 40                                                                {Autres}
# 41                        {Agent Polyvalent, Agent d'Entretien, Chauffeur}
#
#                                             emploitic  \
# 0   Administration, Finance, Comptabilité & Juridique
# 1                     Administration, Moyens Généraux
# 2     Commercial, Marketing, Communication & Création
# 3                                    Création, Design
# 4                        Vente, Télévente, Assistanat
# 5   Administration, Finance, Comptabilité & Juridique
# 6                   Juridique, Fiscal, Audit, Conseil
# 7                   Juridique, Fiscal, Audit, Conseil
# 8                     Journalisme, Médias, Traduction
# 9                 Ingénierie, Industrie, Construction
# 10                     Production, Méthode, Industrie
# 11                     Production, Méthode, Industrie
# 12                             Maintenance, Entretien
# 13                  Juridique, Fiscal, Audit, Conseil
# 14                Chantier, Métiers BTP, Architecture
# 15          Informatique, Télécommunication & Réseaux
# 16     Informatique, Systèmes d'Information, Internet
# 17     Informatique, Systèmes d'Information, Internet
# 18    Commercial, Marketing, Communication & Création
# 19                                   Création, Design
# 20                                   Création, Design
# 21    Commercial, Marketing, Communication & Création
# 22                           Marketing, Communication
# 23    Commercial, Marketing, Communication & Création
# 24                           Marketing, Communication
# 25                   Qualité, Sécurité, Environnement
# 26                   Qualité, Sécurité, Environnement
# 27                   Qualité, Sécurité, Environnement
# 28    Santé, Médical, Pharmaceutique, Délégué Médical
# 29        Hôtellerie, Tourisme, Restauration, Loisirs
# 30        Hôtellerie, Tourisme, Restauration, Loisirs
# 31        Hôtellerie, Tourisme, Restauration, Loisirs
# 32                Logistique, Achat, Stock, Transport
# 33                Logistique, Achat, Stock, Transport
# 34                Logistique, Achat, Stock, Transport
# 35                Ingénierie, Industrie, Construction
# 36                    Ingénierie, Etudes, Projet, R&D
# 37                    Ingénierie, Etudes, Projet, R&D
# 38                    Ingénierie, Etudes, Projet, R&D
# 39                           Métiers de l'Agriculture
# 40                                             Autres
# 41                      Ouvriers Qualifiés, Chauffeur
#
#               emploitic_name  \
# 0             Administration
# 1             Administration
# 2                   Création
# 3                   Création
# 4                      Vente
# 5                  Juridique
# 6                  Juridique
# 7                     Fiscal
# 8                 Traduction
# 9                  Industrie
# 10                 Industrie
# 11                Production
# 12               Maintenance
# 13                     Audit
# 14              Architecture
# 15              Informatique
# 16              Informatique
# 17    Systèmes d'Information
# 18                  Création
# 19                  Création
# 20                    Design
# 21                 Marketing
# 22                 Marketing
# 23             Communication
# 24             Communication
# 25                   Qualité
# 26                  Sécurité
# 27             Environnement
# 28            Pharmaceutique
# 29                  Tourisme
# 30                Hôtellerie
# 31              Restauration
# 32                 Transport
# 33                     Achat
# 34                Logistique
# 35                Ingénierie
# 36                Ingénierie
# 37                    Projet
# 38                       R&D
# 39  Métiers de l'Agriculture
# 40                    Autres
# 41                 Chauffeur
#
#                                          emploitic_set  \
# 0   {Finance, Comptabilité, Juridique, Administration}
# 1                    {Moyens Généraux, Administration}
# 2     {Marketing, Commercial, Création, Communication}
# 3                                   {Création, Design}
# 4                       {Assistanat, Vente, Télévente}
# 5   {Finance, Comptabilité, Juridique, Administration}
# 6                  {Audit, Conseil, Juridique, Fiscal}
# 7                  {Audit, Conseil, Juridique, Fiscal}
# 8                    {Médias, Traduction, Journalisme}
# 9                {Construction, Ingénierie, Industrie}
# 10                    {Production, Industrie, Méthode}
# 11                    {Production, Industrie, Méthode}
# 12                            {Maintenance, Entretien}
# 13                 {Audit, Conseil, Juridique, Fiscal}
# 14               {Chantier, Architecture, Métiers BTP}
# 15          {Télécommunication, Réseaux, Informatique}
# 16    {Systèmes d'Information, Informatique, Internet}
# 17    {Systèmes d'Information, Informatique, Internet}
# 18    {Marketing, Commercial, Création, Communication}
# 19                                  {Création, Design}
# 20                                  {Création, Design}
# 21    {Marketing, Commercial, Création, Communication}
# 22                          {Marketing, Communication}
# 23    {Marketing, Commercial, Création, Communication}
# 24                          {Marketing, Communication}
# 25                  {Environnement, Sécurité, Qualité}
# 26                  {Environnement, Sécurité, Qualité}
# 27                  {Environnement, Sécurité, Qualité}
# 28   {Pharmaceutique, Santé, Délégué Médical, Médical}
# 29       {Restauration, Tourisme, Hôtellerie, Loisirs}
# 30       {Restauration, Tourisme, Hôtellerie, Loisirs}
# 31       {Restauration, Tourisme, Hôtellerie, Loisirs}
# 32               {Transport, Logistique, Achat, Stock}
# 33               {Transport, Logistique, Achat, Stock}
# 34               {Transport, Logistique, Achat, Stock}
# 35               {Construction, Ingénierie, Industrie}
# 36                   {R&D, Projet, Ingénierie, Etudes}
# 37                   {R&D, Projet, Ingénierie, Etudes}
# 38                   {R&D, Projet, Ingénierie, Etudes}
# 39                          {Métiers de l'Agriculture}
# 40                                            {Autres}
# 41                     {Ouvriers Qualifiés, Chauffeur}
#
#                                                                                                  union  \
# 0                       {Finance, Accueil, Services Généraux, Comptabilité, Juridique, Administration}
# 1                                        {Accueil, Services Généraux, Moyens Généraux, Administration}
# 2                                {Création, Communication, Culture, Marketing, Commercial, Spectacles}
# 3                                                              {Création, Culture, Spectacles, Design}
# 4                                               {Commerce, Distribution, Télévente, Assistanat, Vente}
# 5                                           {Finance, Fiscal, Comptabilité, Juridique, Administration}
# 6                                                                  {Conseil, Fiscal, Audit, Juridique}
# 7                                                                  {Conseil, Fiscal, Audit, Juridique}
# 8                                       {Traduction, Edition, Imprimerie, Presse, Médias, Journalisme}
# 9       {Production, Electrique et Électrotechnique, Ingénierie, Maintenance, Construction, Industrie}
# 10                       {Production, Electrique et Électrotechnique, Méthode, Maintenance, Industrie}
# 11                       {Production, Electrique et Électrotechnique, Méthode, Maintenance, Industrie}
# 12                     {Production, Electrique et Électrotechnique, Maintenance, Entretien, Industrie}
# 13                                      {Fiscal, Finances, Compta, Conseil, Audit, Juridique, Gestion}
# 14                               {Paysage, Architecture, Immobilier, Urbanisme, Chantier, Métiers BTP}
# 15  {Analyse et Science des Données, Systèmes d'Information, Télécommunication, Réseaux, Informatique}
# 16                    {Analyse et Science des Données, Systèmes d'Information, Informatique, Internet}
# 17                    {Analyse et Science des Données, Systèmes d'Information, Informatique, Internet}
# 18                         {Création, Médias Numériques, Communication, Marketing, Commercial, Design}
# 19                                                               {Création, Médias Numériques, Design}
# 20                                                               {Création, Médias Numériques, Design}
# 21                                                {RP, Création, Communication, Marketing, Commercial}
# 22                                                                      {RP, Communication, Marketing}
# 23                                                {RP, Création, Communication, Marketing, Commercial}
# 24                                                                      {RP, Communication, Marketing}
# 25                                                                  {Environnement, Qualité, Sécurité}
# 26                                                                  {Environnement, Qualité, Sécurité}
# 27                                                                  {Environnement, Qualité, Sécurité}
# 28                                    {Pharmaceutique, Santé Hopital, Santé, Médical, Délégué Médical}
# 29                                                       {Restauration, Loisirs, Tourisme, Hôtellerie}
# 30                                                       {Restauration, Loisirs, Tourisme, Hôtellerie}
# 31                                                       {Restauration, Loisirs, Tourisme, Hôtellerie}
# 32                                                    {Transport, Achat, Emballage, Stock, Logistique}
# 33                                                    {Transport, Achat, Emballage, Stock, Logistique}
# 34                                                    {Transport, Achat, Emballage, Stock, Logistique}
# 35                                 {Industrie, Bureau d'Études, Ingénierie, R&D, Projet, Construction}
# 36                                                  {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 37                                                  {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 38                                                  {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 39                                                                  {Métiers de l'Agriculture, Nature}
# 40                                                                                            {Autres}
# 41                                {Agent d'Entretien, Chauffeur, Agent Polyvalent, Ouvriers Qualifiés}
#
#                                                                                            union_str
# 0                       Accueil, Administration, Comptabilité, Finance, Juridique, Services Généraux
# 1                                        Accueil, Administration, Moyens Généraux, Services Généraux
# 2                                Commercial, Communication, Création, Culture, Marketing, Spectacles
# 3                                                              Création, Culture, Design, Spectacles
# 4                                               Assistanat, Commerce, Distribution, Télévente, Vente
# 5                                           Administration, Comptabilité, Finance, Fiscal, Juridique
# 6                                                                  Audit, Conseil, Fiscal, Juridique
# 7                                                                  Audit, Conseil, Fiscal, Juridique
# 8                                       Edition, Imprimerie, Journalisme, Médias, Presse, Traduction
# 9       Construction, Electrique et Électrotechnique, Industrie, Ingénierie, Maintenance, Production
# 10                       Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 11                       Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 12                     Electrique et Électrotechnique, Entretien, Industrie, Maintenance, Production
# 13                                      Audit, Compta, Conseil, Finances, Fiscal, Gestion, Juridique
# 14                               Architecture, Chantier, Immobilier, Métiers BTP, Paysage, Urbanisme
# 15  Analyse et Science des Données, Informatique, Réseaux, Systèmes d'Information, Télécommunication
# 16                    Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 17                    Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 18                         Commercial, Communication, Création, Design, Marketing, Médias Numériques
# 19                                                               Création, Design, Médias Numériques
# 20                                                               Création, Design, Médias Numériques
# 21                                                Commercial, Communication, Création, Marketing, RP
# 22                                                                      Communication, Marketing, RP
# 23                                                Commercial, Communication, Création, Marketing, RP
# 24                                                                      Communication, Marketing, RP
# 25                                                                  Environnement, Qualité, Sécurité
# 26                                                                  Environnement, Qualité, Sécurité
# 27                                                                  Environnement, Qualité, Sécurité
# 28                                    Délégué Médical, Médical, Pharmaceutique, Santé, Santé Hopital
# 29                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 30                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 31                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 32                                                    Achat, Emballage, Logistique, Stock, Transport
# 33                                                    Achat, Emballage, Logistique, Stock, Transport
# 34                                                    Achat, Emballage, Logistique, Stock, Transport
# 35                                 Bureau d'Études, Construction, Industrie, Ingénierie, Projet, R&D
# 36                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 37                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 38                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 39                                                                  Métiers de l'Agriculture, Nature
# 40                                                                                            Autres
# 41                                Agent Polyvalent, Agent d'Entretien, Chauffeur, Ouvriers Qualifiés

# %%
# get the rows where the two sources have 2 or more names in commun
# these are almost certainly to be valid standardizations
# other rows need further inspection
merged_filtered = merged_expld[
    merged_expld.duplicated(["emploi_partner", "emploitic"], keep=False)
].copy()
merged_filtered["replace_emploi_partner"] = merged_filtered["union"] != merged_filtered["emploi_partner_set"]
merged_filtered["replace_emploitic"] = merged_filtered["union"] != merged_filtered["emploitic_set"]
merged_filtered = merged_filtered.sort_values("emploi_partner")
merged_filtered
# Out:
#                                                           emploi_partner  \
# 19                                   Création, Design, Médias Numériques
# 20                                   Création, Design, Médias Numériques
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 11    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 16  Informatique, Systèmes d'Information, Analyse et Science des Données
# 17  Informatique, Systèmes d'Information, Analyse et Science des Données
# 38                              Ingénierie, Bureau d'Études, Projet, R&D
# 36                              Ingénierie, Bureau d'Études, Projet, R&D
# 37                              Ingénierie, Bureau d'Études, Projet, R&D
# 6                                                      Juridique, Fiscal
# 7                                                      Juridique, Fiscal
# 23                                          Marketing, Communication, RP
# 21                                          Marketing, Communication, RP
# 22                                          Marketing, Communication, RP
# 24                                          Marketing, Communication, RP
# 25                                      Qualité, Sécurité, Environnement
# 26                                      Qualité, Sécurité, Environnement
# 27                                      Qualité, Sécurité, Environnement
# 29                                    Tourisme, Hôtellerie, Restauration
# 30                                    Tourisme, Hôtellerie, Restauration
# 31                                    Tourisme, Hôtellerie, Restauration
# 32                               Transport, Achat, Logistique, Emballage
# 33                               Transport, Achat, Logistique, Emballage
# 34                               Transport, Achat, Logistique, Emballage
#
#        emploi_partner_name  \
# 19                Création
# 20                  Design
# 10               Industrie
# 11              Production
# 16            Informatique
# 17  Systèmes d'Information
# 38                     R&D
# 36              Ingénierie
# 37                  Projet
# 6                Juridique
# 7                   Fiscal
# 23           Communication
# 21               Marketing
# 22               Marketing
# 24           Communication
# 25                 Qualité
# 26                Sécurité
# 27           Environnement
# 29                Tourisme
# 30              Hôtellerie
# 31            Restauration
# 32               Transport
# 33                   Achat
# 34              Logistique
#
#                                                         emploi_partner_set  \
# 19                                   {Création, Design, Médias Numériques}
# 20                                   {Création, Design, Médias Numériques}
# 10    {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 11    {Production, Electrique et Électrotechnique, Maintenance, Industrie}
# 16  {Analyse et Science des Données, Systèmes d'Information, Informatique}
# 17  {Analyse et Science des Données, Systèmes d'Information, Informatique}
# 38                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 36                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 37                              {R&D, Bureau d'Études, Ingénierie, Projet}
# 6                                                      {Juridique, Fiscal}
# 7                                                      {Juridique, Fiscal}
# 23                                          {RP, Marketing, Communication}
# 21                                          {RP, Marketing, Communication}
# 22                                          {RP, Marketing, Communication}
# 24                                          {RP, Marketing, Communication}
# 25                                      {Environnement, Sécurité, Qualité}
# 26                                      {Environnement, Sécurité, Qualité}
# 27                                      {Environnement, Sécurité, Qualité}
# 29                                    {Restauration, Tourisme, Hôtellerie}
# 30                                    {Restauration, Tourisme, Hôtellerie}
# 31                                    {Restauration, Tourisme, Hôtellerie}
# 32                               {Logistique, Transport, Achat, Emballage}
# 33                               {Logistique, Transport, Achat, Emballage}
# 34                               {Logistique, Transport, Achat, Emballage}
#
#                                           emploitic          emploitic_name  \
# 19                                 Création, Design                Création
# 20                                 Création, Design                  Design
# 10                   Production, Méthode, Industrie               Industrie
# 11                   Production, Méthode, Industrie              Production
# 16   Informatique, Systèmes d'Information, Internet            Informatique
# 17   Informatique, Systèmes d'Information, Internet  Systèmes d'Information
# 38                  Ingénierie, Etudes, Projet, R&D                     R&D
# 36                  Ingénierie, Etudes, Projet, R&D              Ingénierie
# 37                  Ingénierie, Etudes, Projet, R&D                  Projet
# 6                 Juridique, Fiscal, Audit, Conseil               Juridique
# 7                 Juridique, Fiscal, Audit, Conseil                  Fiscal
# 23  Commercial, Marketing, Communication & Création           Communication
# 21  Commercial, Marketing, Communication & Création               Marketing
# 22                         Marketing, Communication               Marketing
# 24                         Marketing, Communication           Communication
# 25                 Qualité, Sécurité, Environnement                 Qualité
# 26                 Qualité, Sécurité, Environnement                Sécurité
# 27                 Qualité, Sécurité, Environnement           Environnement
# 29      Hôtellerie, Tourisme, Restauration, Loisirs                Tourisme
# 30      Hôtellerie, Tourisme, Restauration, Loisirs              Hôtellerie
# 31      Hôtellerie, Tourisme, Restauration, Loisirs            Restauration
# 32              Logistique, Achat, Stock, Transport               Transport
# 33              Logistique, Achat, Stock, Transport                   Achat
# 34              Logistique, Achat, Stock, Transport              Logistique
#
#                                        emploitic_set  \
# 19                                {Création, Design}
# 20                                {Création, Design}
# 10                  {Production, Industrie, Méthode}
# 11                  {Production, Industrie, Méthode}
# 16  {Systèmes d'Information, Informatique, Internet}
# 17  {Systèmes d'Information, Informatique, Internet}
# 38                 {R&D, Projet, Ingénierie, Etudes}
# 36                 {R&D, Projet, Ingénierie, Etudes}
# 37                 {R&D, Projet, Ingénierie, Etudes}
# 6                {Audit, Conseil, Juridique, Fiscal}
# 7                {Audit, Conseil, Juridique, Fiscal}
# 23  {Marketing, Commercial, Création, Communication}
# 21  {Marketing, Commercial, Création, Communication}
# 22                        {Marketing, Communication}
# 24                        {Marketing, Communication}
# 25                {Environnement, Sécurité, Qualité}
# 26                {Environnement, Sécurité, Qualité}
# 27                {Environnement, Sécurité, Qualité}
# 29     {Restauration, Tourisme, Hôtellerie, Loisirs}
# 30     {Restauration, Tourisme, Hôtellerie, Loisirs}
# 31     {Restauration, Tourisme, Hôtellerie, Loisirs}
# 32             {Transport, Logistique, Achat, Stock}
# 33             {Transport, Logistique, Achat, Stock}
# 34             {Transport, Logistique, Achat, Stock}
#
#                                                                                union  \
# 19                                             {Création, Médias Numériques, Design}
# 20                                             {Création, Médias Numériques, Design}
# 10     {Production, Electrique et Électrotechnique, Méthode, Maintenance, Industrie}
# 11     {Production, Electrique et Électrotechnique, Méthode, Maintenance, Industrie}
# 16  {Analyse et Science des Données, Systèmes d'Information, Informatique, Internet}
# 17  {Analyse et Science des Données, Systèmes d'Information, Informatique, Internet}
# 38                                {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 36                                {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 37                                {Bureau d'Études, Ingénierie, Etudes, R&D, Projet}
# 6                                                {Conseil, Fiscal, Audit, Juridique}
# 7                                                {Conseil, Fiscal, Audit, Juridique}
# 23                              {RP, Création, Communication, Marketing, Commercial}
# 21                              {RP, Création, Communication, Marketing, Commercial}
# 22                                                    {RP, Communication, Marketing}
# 24                                                    {RP, Communication, Marketing}
# 25                                                {Environnement, Qualité, Sécurité}
# 26                                                {Environnement, Qualité, Sécurité}
# 27                                                {Environnement, Qualité, Sécurité}
# 29                                     {Restauration, Loisirs, Tourisme, Hôtellerie}
# 30                                     {Restauration, Loisirs, Tourisme, Hôtellerie}
# 31                                     {Restauration, Loisirs, Tourisme, Hôtellerie}
# 32                                  {Transport, Achat, Emballage, Stock, Logistique}
# 33                                  {Transport, Achat, Emballage, Stock, Logistique}
# 34                                  {Transport, Achat, Emballage, Stock, Logistique}
#
#                                                                          union_str  \
# 19                                             Création, Design, Médias Numériques
# 20                                             Création, Design, Médias Numériques
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 11     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 16  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 17  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 38                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 36                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 37                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 6                                                Audit, Conseil, Fiscal, Juridique
# 7                                                Audit, Conseil, Fiscal, Juridique
# 23                              Commercial, Communication, Création, Marketing, RP
# 21                              Commercial, Communication, Création, Marketing, RP
# 22                                                    Communication, Marketing, RP
# 24                                                    Communication, Marketing, RP
# 25                                                Environnement, Qualité, Sécurité
# 26                                                Environnement, Qualité, Sécurité
# 27                                                Environnement, Qualité, Sécurité
# 29                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 30                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 31                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 32                                  Achat, Emballage, Logistique, Stock, Transport
# 33                                  Achat, Emballage, Logistique, Stock, Transport
# 34                                  Achat, Emballage, Logistique, Stock, Transport
#
#     replace_emploi_partner  replace_emploitic
# 19                   False               True
# 20                   False               True
# 10                    True               True
# 11                    True               True
# 16                    True               True
# 17                    True               True
# 38                    True               True
# 36                    True               True
# 37                    True               True
# 6                     True              False
# 7                     True              False
# 23                    True               True
# 21                    True               True
# 22                   False               True
# 24                   False               True
# 25                   False              False
# 26                   False              False
# 27                   False              False
# 29                    True              False
# 30                    True              False
# 31                    True              False
# 32                    True               True
# 33                    True               True
# 34                    True               True

# %%
# the replacements to be used in each source data transformation step
df_values_to_replace_ep = merged_filtered.loc[
    merged_filtered["replace_emploi_partner"], ["emploi_partner", "union_str"]
].drop_duplicates()
df_values_to_replace_em = merged_filtered.loc[
    merged_filtered["replace_emploitic"], ["emploitic", "union_str"]
].drop_duplicates()
display(df_values_to_replace_ep)
display(df_values_to_replace_em)
# Out:
#                                                           emploi_partner  \
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 16  Informatique, Systèmes d'Information, Analyse et Science des Données
# 38                              Ingénierie, Bureau d'Études, Projet, R&D
# 6                                                      Juridique, Fiscal
# 23                                          Marketing, Communication, RP
# 29                                    Tourisme, Hôtellerie, Restauration
# 32                               Transport, Achat, Logistique, Emballage
#
#                                                                          union_str
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 16  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 38                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 6                                                Audit, Conseil, Fiscal, Juridique
# 23                              Commercial, Communication, Création, Marketing, RP
# 29                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 32                                  Achat, Emballage, Logistique, Stock, Transport
#                                           emploitic  \
# 19                                 Création, Design
# 10                   Production, Méthode, Industrie
# 16   Informatique, Systèmes d'Information, Internet
# 38                  Ingénierie, Etudes, Projet, R&D
# 23  Commercial, Marketing, Communication & Création
# 22                         Marketing, Communication
# 32              Logistique, Achat, Stock, Transport
#
#                                                                          union_str
# 19                                             Création, Design, Médias Numériques
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 16  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 38                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 23                              Commercial, Communication, Création, Marketing, RP
# 22                                                    Communication, Marketing, RP
# 32                                  Achat, Emballage, Logistique, Stock, Transport

# %%
values_to_replace_ep = dict(zip(
    df_values_to_replace_ep["emploi_partner"], df_values_to_replace_ep["union_str"]
))

values_to_replace_em = dict(zip(
    df_values_to_replace_em["emploitic"], df_values_to_replace_em["union_str"]
))
display(values_to_replace_ep)
display(values_to_replace_em)
# Out:
# {'Industrie, Electrique et Électrotechnique, Production, Maintenance': 'Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production',
#  "Informatique, Systèmes d'Information, Analyse et Science des Données": "Analyse et Science des Données, Informatique, Internet, Systèmes d'Information",
#  "Ingénierie, Bureau d'Études, Projet, R&D": "Bureau d'Études, Etudes, Ingénierie, Projet, R&D",
#  'Juridique, Fiscal': 'Audit, Conseil, Fiscal, Juridique',
#  'Marketing, Communication, RP': 'Commercial, Communication, Création, Marketing, RP',
#  'Tourisme, Hôtellerie, Restauration': 'Hôtellerie, Loisirs, Restauration, Tourisme',
#  'Transport, Achat, Logistique, Emballage': 'Achat, Emballage, Logistique, Stock, Transport'}
# {'Création, Design': 'Création, Design, Médias Numériques',
#  'Production, Méthode, Industrie': 'Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production',
#  "Informatique, Systèmes d'Information, Internet": "Analyse et Science des Données, Informatique, Internet, Systèmes d'Information",
#  'Ingénierie, Etudes, Projet, R&D': "Bureau d'Études, Etudes, Ingénierie, Projet, R&D",
#  'Commercial, Marketing, Communication & Création': 'Commercial, Communication, Création, Marketing, RP',
#  'Marketing, Communication': 'Communication, Marketing, RP',
#  'Logistique, Achat, Stock, Transport': 'Achat, Emballage, Logistique, Stock, Transport'}

# %%
# inspect the remaining rows and look for matchable values
# that were missed due to subtle changes (e.g Réseaux vs Réseau)
unmatched_ep_df = ep_df[
    ~ep_df["emploi_partner"].isin(values_to_replace_ep.keys())
]
unmatched_em_df = em_df[
    ~em_df["emploitic"].isin(values_to_replace_em.keys())
]
merged_unmatched = pd.merge(
    unmatched_ep_df,
    unmatched_em_df,
    left_on="emploi_partner",
    right_on="emploitic",
    how="outer"
)
merged_unmatched[["emploi_partner", "emploitic"]]
# Out:
#                                             emploi_partner  \
# 0              Accueil, Administration - Services Généraux
# 1                                                      NaN
# 2                                                      NaN
# 3                                          Armées, Défense
# 4                                                      NaN
# 5                         Audit, Gestion, Finances, Compta
# 6                                                      NaN
# 7                                                   Autres
# 8                                Banque, Bourse, Assurance
# 9                                     Batiment, Équipement
# 10                                                     NaN
# 11          Chauffeur, Agent d'Entretien, Agent Polyvalent
# 12                                        Chimie, Biologie
# 13                             Collectivité Secteur Public
# 14                           Commerce, Distribution, Vente
# 15                                                     NaN
# 16                                                     NaN
# 17            Contact Client, SAV, Centre d'Appel, Enquête
# 18                           Création, Culture, Spectacles
# 19                     Création, Design, Médias Numériques
# 20  Direction, Entrepreneuriat, Cadres Dirigeants, Experts
# 21                 Edition, Imprimerie, Presse, Traduction
# 22                        Formation, Enseignement, Langues
# 23                                                     NaN
# 24            Immobilier, Architecture, Urbanisme, Paysage
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# 30                                              Management
# 31                                      Mode, Luxe, Beauté
# 32                                                     NaN
# 33                       Métiers Manuels et de l'Artisanat
# 34                                                     NaN
# 35                        Métiers de l'Agriculture, Nature
# 36                                                     NaN
# 37                    Ouvriés, Maneouvre, Manutentionnaire
# 38                                          Petite Enfance
# 39                        Qualité, Sécurité, Environnement
# 40                                                     NaN
# 41                                 Ressources Humaines-Grh
# 42                           Santé Hopital, Pharmaceutique
# 43                                                     NaN
# 44                                                     NaN
# 45                                                Services
# 46           Social, Médico-Social, Services À la Personne
# 47                                                   Sport
# 48                                                  Sports
# 49                                                     NaN
# 50                    Télécommunications, Systèmes, Réseau
# 51                                                     NaN
#
#                                             emploitic
# 0                                                 NaN
# 1   Administration, Finance, Comptabilité & Juridique
# 2                     Administration, Moyens Généraux
# 3                                                 NaN
# 4                             Assistanat, Secrétariat
# 5                                                 NaN
# 6                                               Autre
# 7                                              Autres
# 8                                                 NaN
# 9                                                 NaN
# 10                Chantier, Métiers BTP, Architecture
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15    Commercial, Technico Commercial, Service Client
# 16                              Comptabilité, Finance
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23        Hôtellerie, Tourisme, Restauration, Loisirs
# 24                                                NaN
# 25          Informatique, Télécommunication & Réseaux
# 26                Ingénierie, Industrie, Construction
# 27                    Journalisme, Médias, Traduction
# 28                  Juridique, Fiscal, Audit, Conseil
# 29                             Maintenance, Entretien
# 30                                                NaN
# 31                                                NaN
# 32                       Métiers Banque et Assurances
# 33                                                NaN
# 34                           Métiers de l'Agriculture
# 35                                                NaN
# 36                      Ouvriers Qualifiés, Chauffeur
# 37                                                NaN
# 38                                                NaN
# 39                   Qualité, Sécurité, Environnement
# 40             Responsable Commercial, Grands Comptes
# 41                                                NaN
# 42                                                NaN
# 43    Santé, Médical, Pharmaceutique, Délégué Médical
# 44                          Santé, Médical, Pharmacie
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                         Télécommunication, Réseaux
# 50                                                NaN
# 51                       Vente, Télévente, Assistanat
