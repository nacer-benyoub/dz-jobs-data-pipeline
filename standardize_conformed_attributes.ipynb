# %% [markdown]
# # Standardization Utility

# %% [markdown]
# ### Overview
# This is a semi-automated process that can help in standardizing similar values of conformed attributes (dimensions) pulled from two different sources. It works under the following circumstances:
# - Attribute values come from two sources.
# - Attribute values are mainly lists.
#
# ### Process
# - Loading and preprocessing
# - Matching
#     - the values are split on punctuation (`,`, `-`, `&`) into the individial names which are then exploded and used for joining the sources.
#     - then values that contain >= 2 common individual names are considered as valid matches.
#     - union of the two values are created from the valid matches.
#     - matches are exported as a dictionary mapping the value and the union for each source.
# - Other unmatched values are then outlined for further review.
#
# ### Notes
# - This is a semi automatic utility, so manual review is necessary in every stage of th process to point out minor nuances that prevent values from being matched (.e.g plural vs singular forms, `ing` forms)

# %%
import requests
import pandas as pd
from dz_jobs_aggregator.utils import french_titlecase
import re

pd.set_option("max_colwidth", 600)
LANG = "fr"

# %%
# ---- Emploi Partner Transformations ----
emploi_partner_dimenion_url = "https://api-v4.emploipartner.com/api/params_experiences"
response = requests.get(emploi_partner_dimenion_url, headers={"Accept-Language": LANG})
label_key = "label"
ep_df = pd.DataFrame(response.json()["hydra:member"])[[label_key]].drop_duplicates()

# Replace any slashes with commas.
ep_df[label_key] = ep_df[label_key].apply(lambda x: re.sub(r"\s*/\s*", ", ", x))

# Apply custom titlecase
ep_df[label_key] = ep_df[label_key].apply(french_titlecase)

ep_df = ep_df.rename(columns={label_key: "emploi_partner"})

# ---- Emploitic Transformations ----
emploitic_dimension_url = f"https://emploitic.com/api/v4/lists/annees-dexperience?&lang={LANG}&per_page=1000"
response = requests.get(emploitic_dimension_url)
em_label_key = "label"
em_df = pd.DataFrame(response.json()["collection"])[[em_label_key]].drop_duplicates()

# Apply custom titlecase
# em_df[em_label_key] = em_df[em_label_key].apply(french_titlecase)
em_df = em_df.rename(columns={em_label_key: "emploitic"})

# ---- Merge Both Data Sources ----
merged = pd.merge(ep_df, em_df, left_on="emploi_partner", right_on="emploitic", how="outer")
# merged.to_json("merged_functions.json", orient="records", force_ascii=False)
merged
# Out:
#        emploi_partner        emploitic
# 0           1 À 2 Ans        1 À 2 Ans
# 1           2 À 3 Ans              NaN
# 2           3 À 4 Ans              NaN
# 3                 NaN        3 À 5 Ans
# 4           4 À 5 Ans              NaN
# 5          5 À 10 Ans              NaN
# 6                 NaN       6 À 10 Ans
# 7   Aucune Expérience              NaN
# 8         Indifférent              NaN
# 9                 NaN    Moins D’un An
# 10      Moins de 1 An              NaN
# 11     Plus de 10 Ans   Plus de 10 Ans
# 12                NaN  Sans Expérience

# %%
# split on (',', '-' or '&')
split_pattern = "\s*,\s*|\s*-\s*|\s+&\s*|\s*&\s+"
ep_df["emploi_partner_name"] = ep_df["emploi_partner"].apply(
    lambda x: re.split(split_pattern, x)
)
ep_df["emploi_partner_set"] = ep_df["emploi_partner_name"].copy().apply(lambda x: set(x))

em_df["emploitic_name"] = em_df["emploitic"].apply(
    lambda x: re.split(split_pattern, x)
)
em_df["emploitic_set"] = em_df["emploitic_name"].copy().apply(lambda x: set(x))

ep_df_expld = ep_df.explode("emploi_partner_name")
em_df_expld = em_df.explode("emploitic_name")
merged_expld = pd.merge(
    ep_df_expld,
    em_df_expld,
    left_on="emploi_partner_name",
    right_on="emploitic_name",
)
set_union = lambda row: row["emploi_partner_set"] | row["emploitic_set"]
set_to_str = lambda row: ', '.join(sorted(row["union"]))
merged_expld["union"] = merged_expld.apply(set_union, axis="columns")
merged_expld["union_str"] = merged_expld.apply(set_to_str, axis="columns")
merged_expld
# Out:
#                                                           emploi_partner  \
# 0                            Accueil, Administration - Services Généraux
# 1                            Accueil, Administration - Services Généraux
# 2                                          Création, Culture, Spectacles
# 3                                          Création, Culture, Spectacles
# 4                                          Commerce, Distribution, Vente
# 5                                                      Juridique, Fiscal
# 6                                                      Juridique, Fiscal
# 7                                                      Juridique, Fiscal
# 8                                Edition, Imprimerie, Presse, Traduction
# 9     Industrie, Electrique et Électrotechnique, Production, Maintenance
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 11    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 12    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 13                                      Formation, Enseignement, Langues
# 14                                      Formation, Enseignement, Langues
# 15                                      Audit, Gestion, Finances, Compta
# 16                          Immobilier, Architecture, Urbanisme, Paysage
# 17  Informatique, Systèmes d'Information, Analyse et Science des Données
# 18  Informatique, Systèmes d'Information, Analyse et Science des Données
# 19  Informatique, Systèmes d'Information, Analyse et Science des Données
# 20                                   Création, Design, Médias Numériques
# 21                                   Création, Design, Médias Numériques
# 22                                   Création, Design, Médias Numériques
# 23                                          Marketing, Communication, RP
# 24                                          Marketing, Communication, RP
# 25                                          Marketing, Communication, RP
# 26                                          Marketing, Communication, RP
# 27                                      Qualité, Sécurité, Environnement
# 28                                      Qualité, Sécurité, Environnement
# 29                                      Qualité, Sécurité, Environnement
# 30                                         Santé Hopital, Pharmaceutique
# 31                                    Tourisme, Hôtellerie, Restauration
# 32                                    Tourisme, Hôtellerie, Restauration
# 33                                    Tourisme, Hôtellerie, Restauration
# 34                               Transport, Achat, Logistique, Emballage
# 35                               Transport, Achat, Logistique, Emballage
# 36                               Transport, Achat, Logistique, Emballage
# 37                              Ingénierie, Bureau d'Études, Projet, R&D
# 38                              Ingénierie, Bureau d'Études, Projet, R&D
# 39                              Ingénierie, Bureau d'Études, Projet, R&D
# 40                              Ingénierie, Bureau d'Études, Projet, R&D
# 41                                      Métiers de l'Agriculture, Nature
# 42                                                                Autres
# 43                        Chauffeur, Agent d'Entretien, Agent Polyvalent
#
#          emploi_partner_name  \
# 0             Administration
# 1             Administration
# 2                   Création
# 3                   Création
# 4                      Vente
# 5                  Juridique
# 6                  Juridique
# 7                     Fiscal
# 8                 Traduction
# 9                  Industrie
# 10                 Industrie
# 11                Production
# 12               Maintenance
# 13                 Formation
# 14              Enseignement
# 15                     Audit
# 16              Architecture
# 17              Informatique
# 18              Informatique
# 19    Systèmes d'Information
# 20                  Création
# 21                  Création
# 22                    Design
# 23                 Marketing
# 24                 Marketing
# 25             Communication
# 26             Communication
# 27                   Qualité
# 28                  Sécurité
# 29             Environnement
# 30            Pharmaceutique
# 31                  Tourisme
# 32                Hôtellerie
# 33              Restauration
# 34                 Transport
# 35                     Achat
# 36                Logistique
# 37                Ingénierie
# 38                Ingénierie
# 39                    Projet
# 40                       R&D
# 41  Métiers de l'Agriculture
# 42                    Autres
# 43                 Chauffeur
#
#                                                         emploi_partner_set  \
# 0                             {Accueil, Administration, Services Généraux}
# 1                             {Accueil, Administration, Services Généraux}
# 2                                          {Spectacles, Culture, Création}
# 3                                          {Spectacles, Culture, Création}
# 4                                          {Vente, Distribution, Commerce}
# 5                                                      {Juridique, Fiscal}
# 6                                                      {Juridique, Fiscal}
# 7                                                      {Juridique, Fiscal}
# 8                                {Traduction, Imprimerie, Presse, Edition}
# 9     {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 10    {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 11    {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 12    {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 13                                      {Formation, Langues, Enseignement}
# 14                                      {Formation, Langues, Enseignement}
# 15                                      {Compta, Gestion, Audit, Finances}
# 16                          {Architecture, Paysage, Urbanisme, Immobilier}
# 17  {Systèmes d'Information, Analyse et Science des Données, Informatique}
# 18  {Systèmes d'Information, Analyse et Science des Données, Informatique}
# 19  {Systèmes d'Information, Analyse et Science des Données, Informatique}
# 20                                   {Médias Numériques, Design, Création}
# 21                                   {Médias Numériques, Design, Création}
# 22                                   {Médias Numériques, Design, Création}
# 23                                          {Communication, RP, Marketing}
# 24                                          {Communication, RP, Marketing}
# 25                                          {Communication, RP, Marketing}
# 26                                          {Communication, RP, Marketing}
# 27                                      {Qualité, Sécurité, Environnement}
# 28                                      {Qualité, Sécurité, Environnement}
# 29                                      {Qualité, Sécurité, Environnement}
# 30                                         {Pharmaceutique, Santé Hopital}
# 31                                    {Hôtellerie, Tourisme, Restauration}
# 32                                    {Hôtellerie, Tourisme, Restauration}
# 33                                    {Hôtellerie, Tourisme, Restauration}
# 34                               {Achat, Logistique, Emballage, Transport}
# 35                               {Achat, Logistique, Emballage, Transport}
# 36                               {Achat, Logistique, Emballage, Transport}
# 37                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 38                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 39                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 40                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 41                                      {Métiers de l'Agriculture, Nature}
# 42                                                                {Autres}
# 43                        {Chauffeur, Agent Polyvalent, Agent d'Entretien}
#
#                                             emploitic  \
# 0   Administration, Finance, Comptabilité & Juridique
# 1                     Administration, Moyens Généraux
# 2     Commercial, Marketing, Communication & Création
# 3                                    Création, Design
# 4                        Vente, Télévente, Assistanat
# 5   Administration, Finance, Comptabilité & Juridique
# 6                   Juridique, Fiscal, Audit, Conseil
# 7                   Juridique, Fiscal, Audit, Conseil
# 8                     Journalisme, Médias, Traduction
# 9                 Ingénierie, Industrie, Construction
# 10                     Production, Méthode, Industrie
# 11                     Production, Méthode, Industrie
# 12                             Maintenance, Entretien
# 13                           RH, Personnel, Formation
# 14                            Education, Enseignement
# 15                  Juridique, Fiscal, Audit, Conseil
# 16                Chantier, Métiers BTP, Architecture
# 17          Informatique, Télécommunication & Réseaux
# 18     Informatique, Systèmes d'Information, Internet
# 19     Informatique, Systèmes d'Information, Internet
# 20    Commercial, Marketing, Communication & Création
# 21                                   Création, Design
# 22                                   Création, Design
# 23    Commercial, Marketing, Communication & Création
# 24                           Marketing, Communication
# 25    Commercial, Marketing, Communication & Création
# 26                           Marketing, Communication
# 27                   Qualité, Sécurité, Environnement
# 28                   Qualité, Sécurité, Environnement
# 29                   Qualité, Sécurité, Environnement
# 30    Santé, Médical, Pharmaceutique, Délégué Médical
# 31        Hôtellerie, Tourisme, Restauration, Loisirs
# 32        Hôtellerie, Tourisme, Restauration, Loisirs
# 33        Hôtellerie, Tourisme, Restauration, Loisirs
# 34                Logistique, Achat, Stock, Transport
# 35                Logistique, Achat, Stock, Transport
# 36                Logistique, Achat, Stock, Transport
# 37                Ingénierie, Industrie, Construction
# 38                    Ingénierie, Etudes, Projet, R&D
# 39                    Ingénierie, Etudes, Projet, R&D
# 40                    Ingénierie, Etudes, Projet, R&D
# 41                           Métiers de l'Agriculture
# 42                                             Autres
# 43                      Ouvriers Qualifiés, Chauffeur
#
#               emploitic_name  \
# 0             Administration
# 1             Administration
# 2                   Création
# 3                   Création
# 4                      Vente
# 5                  Juridique
# 6                  Juridique
# 7                     Fiscal
# 8                 Traduction
# 9                  Industrie
# 10                 Industrie
# 11                Production
# 12               Maintenance
# 13                 Formation
# 14              Enseignement
# 15                     Audit
# 16              Architecture
# 17              Informatique
# 18              Informatique
# 19    Systèmes d'Information
# 20                  Création
# 21                  Création
# 22                    Design
# 23                 Marketing
# 24                 Marketing
# 25             Communication
# 26             Communication
# 27                   Qualité
# 28                  Sécurité
# 29             Environnement
# 30            Pharmaceutique
# 31                  Tourisme
# 32                Hôtellerie
# 33              Restauration
# 34                 Transport
# 35                     Achat
# 36                Logistique
# 37                Ingénierie
# 38                Ingénierie
# 39                    Projet
# 40                       R&D
# 41  Métiers de l'Agriculture
# 42                    Autres
# 43                 Chauffeur
#
#                                          emploitic_set  \
# 0   {Finance, Administration, Comptabilité, Juridique}
# 1                    {Moyens Généraux, Administration}
# 2     {Communication, Commercial, Marketing, Création}
# 3                                   {Design, Création}
# 4                       {Assistanat, Vente, Télévente}
# 5   {Finance, Administration, Comptabilité, Juridique}
# 6                  {Conseil, Juridique, Audit, Fiscal}
# 7                  {Conseil, Juridique, Audit, Fiscal}
# 8                    {Journalisme, Traduction, Médias}
# 9                {Construction, Industrie, Ingénierie}
# 10                    {Industrie, Production, Méthode}
# 11                    {Industrie, Production, Méthode}
# 12                            {Maintenance, Entretien}
# 13                          {Formation, RH, Personnel}
# 14                           {Enseignement, Education}
# 15                 {Conseil, Juridique, Audit, Fiscal}
# 16               {Chantier, Métiers BTP, Architecture}
# 17          {Télécommunication, Réseaux, Informatique}
# 18    {Systèmes d'Information, Internet, Informatique}
# 19    {Systèmes d'Information, Internet, Informatique}
# 20    {Communication, Commercial, Marketing, Création}
# 21                                  {Design, Création}
# 22                                  {Design, Création}
# 23    {Communication, Commercial, Marketing, Création}
# 24                          {Communication, Marketing}
# 25    {Communication, Commercial, Marketing, Création}
# 26                          {Communication, Marketing}
# 27                  {Qualité, Sécurité, Environnement}
# 28                  {Qualité, Sécurité, Environnement}
# 29                  {Qualité, Sécurité, Environnement}
# 30   {Délégué Médical, Pharmaceutique, Médical, Santé}
# 31       {Hôtellerie, Loisirs, Tourisme, Restauration}
# 32       {Hôtellerie, Loisirs, Tourisme, Restauration}
# 33       {Hôtellerie, Loisirs, Tourisme, Restauration}
# 34               {Achat, Logistique, Stock, Transport}
# 35               {Achat, Logistique, Stock, Transport}
# 36               {Achat, Logistique, Stock, Transport}
# 37               {Construction, Industrie, Ingénierie}
# 38                   {R&D, Projet, Ingénierie, Etudes}
# 39                   {R&D, Projet, Ingénierie, Etudes}
# 40                   {R&D, Projet, Ingénierie, Etudes}
# 41                          {Métiers de l'Agriculture}
# 42                                            {Autres}
# 43                     {Ouvriers Qualifiés, Chauffeur}
#
#                                                                                                  union  \
# 0                       {Accueil, Finance, Services Généraux, Comptabilité, Juridique, Administration}
# 1                                        {Accueil, Moyens Généraux, Services Généraux, Administration}
# 2                                {Communication, Spectacles, Culture, Commercial, Marketing, Création}
# 3                                                              {Spectacles, Culture, Design, Création}
# 4                                               {Assistanat, Vente, Distribution, Télévente, Commerce}
# 5                                           {Fiscal, Finance, Comptabilité, Juridique, Administration}
# 6                                                                  {Fiscal, Juridique, Audit, Conseil}
# 7                                                                  {Fiscal, Juridique, Audit, Conseil}
# 8                                       {Imprimerie, Traduction, Edition, Médias, Journalisme, Presse}
# 9       {Construction, Production, Maintenance, Ingénierie, Industrie, Electrique et Électrotechnique}
# 10                       {Production, Maintenance, Méthode, Industrie, Electrique et Électrotechnique}
# 11                       {Production, Maintenance, Méthode, Industrie, Electrique et Électrotechnique}
# 12                     {Production, Maintenance, Entretien, Industrie, Electrique et Électrotechnique}
# 13                                                   {Formation, RH, Personnel, Langues, Enseignement}
# 14                                                       {Formation, Education, Langues, Enseignement}
# 15                                      {Fiscal, Finances, Compta, Gestion, Juridique, Audit, Conseil}
# 16                               {Architecture, Chantier, Métiers BTP, Urbanisme, Immobilier, Paysage}
# 17  {Systèmes d'Information, Informatique, Télécommunication, Analyse et Science des Données, Réseaux}
# 18                    {Systèmes d'Information, Informatique, Analyse et Science des Données, Internet}
# 19                    {Systèmes d'Information, Informatique, Analyse et Science des Données, Internet}
# 20                         {Communication, Design, Commercial, Marketing, Médias Numériques, Création}
# 21                                                               {Design, Médias Numériques, Création}
# 22                                                               {Design, Médias Numériques, Création}
# 23                                                {Communication, RP, Commercial, Marketing, Création}
# 24                                                                      {Communication, RP, Marketing}
# 25                                                {Communication, RP, Commercial, Marketing, Création}
# 26                                                                      {Communication, RP, Marketing}
# 27                                                                  {Qualité, Sécurité, Environnement}
# 28                                                                  {Qualité, Sécurité, Environnement}
# 29                                                                  {Qualité, Sécurité, Environnement}
# 30                                    {Délégué Médical, Pharmaceutique, Santé, Santé Hopital, Médical}
# 31                                                       {Hôtellerie, Restauration, Loisirs, Tourisme}
# 32                                                       {Hôtellerie, Restauration, Loisirs, Tourisme}
# 33                                                       {Hôtellerie, Restauration, Loisirs, Tourisme}
# 34                                                    {Stock, Achat, Transport, Emballage, Logistique}
# 35                                                    {Stock, Achat, Transport, Emballage, Logistique}
# 36                                                    {Stock, Achat, Transport, Emballage, Logistique}
# 37                                 {Construction, R&D, Projet, Ingénierie, Industrie, Bureau d'Études}
# 38                                                  {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 39                                                  {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 40                                                  {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 41                                                                  {Métiers de l'Agriculture, Nature}
# 42                                                                                            {Autres}
# 43                                {Chauffeur, Agent Polyvalent, Agent d'Entretien, Ouvriers Qualifiés}
#
#                                                                                            union_str
# 0                       Accueil, Administration, Comptabilité, Finance, Juridique, Services Généraux
# 1                                        Accueil, Administration, Moyens Généraux, Services Généraux
# 2                                Commercial, Communication, Création, Culture, Marketing, Spectacles
# 3                                                              Création, Culture, Design, Spectacles
# 4                                               Assistanat, Commerce, Distribution, Télévente, Vente
# 5                                           Administration, Comptabilité, Finance, Fiscal, Juridique
# 6                                                                  Audit, Conseil, Fiscal, Juridique
# 7                                                                  Audit, Conseil, Fiscal, Juridique
# 8                                       Edition, Imprimerie, Journalisme, Médias, Presse, Traduction
# 9       Construction, Electrique et Électrotechnique, Industrie, Ingénierie, Maintenance, Production
# 10                       Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 11                       Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 12                     Electrique et Électrotechnique, Entretien, Industrie, Maintenance, Production
# 13                                                   Enseignement, Formation, Langues, Personnel, RH
# 14                                                       Education, Enseignement, Formation, Langues
# 15                                      Audit, Compta, Conseil, Finances, Fiscal, Gestion, Juridique
# 16                               Architecture, Chantier, Immobilier, Métiers BTP, Paysage, Urbanisme
# 17  Analyse et Science des Données, Informatique, Réseaux, Systèmes d'Information, Télécommunication
# 18                    Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 19                    Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 20                         Commercial, Communication, Création, Design, Marketing, Médias Numériques
# 21                                                               Création, Design, Médias Numériques
# 22                                                               Création, Design, Médias Numériques
# 23                                                Commercial, Communication, Création, Marketing, RP
# 24                                                                      Communication, Marketing, RP
# 25                                                Commercial, Communication, Création, Marketing, RP
# 26                                                                      Communication, Marketing, RP
# 27                                                                  Environnement, Qualité, Sécurité
# 28                                                                  Environnement, Qualité, Sécurité
# 29                                                                  Environnement, Qualité, Sécurité
# 30                                    Délégué Médical, Médical, Pharmaceutique, Santé, Santé Hopital
# 31                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 32                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 33                                                       Hôtellerie, Loisirs, Restauration, Tourisme
# 34                                                    Achat, Emballage, Logistique, Stock, Transport
# 35                                                    Achat, Emballage, Logistique, Stock, Transport
# 36                                                    Achat, Emballage, Logistique, Stock, Transport
# 37                                 Bureau d'Études, Construction, Industrie, Ingénierie, Projet, R&D
# 38                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 39                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 40                                                  Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 41                                                                  Métiers de l'Agriculture, Nature
# 42                                                                                            Autres
# 43                                Agent Polyvalent, Agent d'Entretien, Chauffeur, Ouvriers Qualifiés

# %%
# get the rows where the two sources have 2 or more names in commun
# these are almost certainly to be valid standardizations
# other rows need further inspection
merged_filtered = merged_expld[
    merged_expld.duplicated(["emploi_partner", "emploitic"], keep=False)
].copy()
merged_filtered["replace_emploi_partner"] = merged_filtered["union"] != merged_filtered["emploi_partner_set"]
merged_filtered["replace_emploitic"] = merged_filtered["union"] != merged_filtered["emploitic_set"]
merged_filtered = merged_filtered.sort_values("emploi_partner")
merged_filtered
# Out:
#                                                           emploi_partner  \
# 21                                   Création, Design, Médias Numériques
# 22                                   Création, Design, Médias Numériques
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 11    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 18  Informatique, Systèmes d'Information, Analyse et Science des Données
# 19  Informatique, Systèmes d'Information, Analyse et Science des Données
# 40                              Ingénierie, Bureau d'Études, Projet, R&D
# 38                              Ingénierie, Bureau d'Études, Projet, R&D
# 39                              Ingénierie, Bureau d'Études, Projet, R&D
# 6                                                      Juridique, Fiscal
# 7                                                      Juridique, Fiscal
# 25                                          Marketing, Communication, RP
# 23                                          Marketing, Communication, RP
# 24                                          Marketing, Communication, RP
# 26                                          Marketing, Communication, RP
# 27                                      Qualité, Sécurité, Environnement
# 28                                      Qualité, Sécurité, Environnement
# 29                                      Qualité, Sécurité, Environnement
# 31                                    Tourisme, Hôtellerie, Restauration
# 32                                    Tourisme, Hôtellerie, Restauration
# 33                                    Tourisme, Hôtellerie, Restauration
# 34                               Transport, Achat, Logistique, Emballage
# 35                               Transport, Achat, Logistique, Emballage
# 36                               Transport, Achat, Logistique, Emballage
#
#        emploi_partner_name  \
# 21                Création
# 22                  Design
# 10               Industrie
# 11              Production
# 18            Informatique
# 19  Systèmes d'Information
# 40                     R&D
# 38              Ingénierie
# 39                  Projet
# 6                Juridique
# 7                   Fiscal
# 25           Communication
# 23               Marketing
# 24               Marketing
# 26           Communication
# 27                 Qualité
# 28                Sécurité
# 29           Environnement
# 31                Tourisme
# 32              Hôtellerie
# 33            Restauration
# 34               Transport
# 35                   Achat
# 36              Logistique
#
#                                                         emploi_partner_set  \
# 21                                   {Médias Numériques, Design, Création}
# 22                                   {Médias Numériques, Design, Création}
# 10    {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 11    {Industrie, Electrique et Électrotechnique, Production, Maintenance}
# 18  {Systèmes d'Information, Analyse et Science des Données, Informatique}
# 19  {Systèmes d'Information, Analyse et Science des Données, Informatique}
# 40                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 38                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 39                              {R&D, Projet, Bureau d'Études, Ingénierie}
# 6                                                      {Juridique, Fiscal}
# 7                                                      {Juridique, Fiscal}
# 25                                          {Communication, RP, Marketing}
# 23                                          {Communication, RP, Marketing}
# 24                                          {Communication, RP, Marketing}
# 26                                          {Communication, RP, Marketing}
# 27                                      {Qualité, Sécurité, Environnement}
# 28                                      {Qualité, Sécurité, Environnement}
# 29                                      {Qualité, Sécurité, Environnement}
# 31                                    {Hôtellerie, Tourisme, Restauration}
# 32                                    {Hôtellerie, Tourisme, Restauration}
# 33                                    {Hôtellerie, Tourisme, Restauration}
# 34                               {Achat, Logistique, Emballage, Transport}
# 35                               {Achat, Logistique, Emballage, Transport}
# 36                               {Achat, Logistique, Emballage, Transport}
#
#                                           emploitic          emploitic_name  \
# 21                                 Création, Design                Création
# 22                                 Création, Design                  Design
# 10                   Production, Méthode, Industrie               Industrie
# 11                   Production, Méthode, Industrie              Production
# 18   Informatique, Systèmes d'Information, Internet            Informatique
# 19   Informatique, Systèmes d'Information, Internet  Systèmes d'Information
# 40                  Ingénierie, Etudes, Projet, R&D                     R&D
# 38                  Ingénierie, Etudes, Projet, R&D              Ingénierie
# 39                  Ingénierie, Etudes, Projet, R&D                  Projet
# 6                 Juridique, Fiscal, Audit, Conseil               Juridique
# 7                 Juridique, Fiscal, Audit, Conseil                  Fiscal
# 25  Commercial, Marketing, Communication & Création           Communication
# 23  Commercial, Marketing, Communication & Création               Marketing
# 24                         Marketing, Communication               Marketing
# 26                         Marketing, Communication           Communication
# 27                 Qualité, Sécurité, Environnement                 Qualité
# 28                 Qualité, Sécurité, Environnement                Sécurité
# 29                 Qualité, Sécurité, Environnement           Environnement
# 31      Hôtellerie, Tourisme, Restauration, Loisirs                Tourisme
# 32      Hôtellerie, Tourisme, Restauration, Loisirs              Hôtellerie
# 33      Hôtellerie, Tourisme, Restauration, Loisirs            Restauration
# 34              Logistique, Achat, Stock, Transport               Transport
# 35              Logistique, Achat, Stock, Transport                   Achat
# 36              Logistique, Achat, Stock, Transport              Logistique
#
#                                        emploitic_set  \
# 21                                {Design, Création}
# 22                                {Design, Création}
# 10                  {Industrie, Production, Méthode}
# 11                  {Industrie, Production, Méthode}
# 18  {Systèmes d'Information, Internet, Informatique}
# 19  {Systèmes d'Information, Internet, Informatique}
# 40                 {R&D, Projet, Ingénierie, Etudes}
# 38                 {R&D, Projet, Ingénierie, Etudes}
# 39                 {R&D, Projet, Ingénierie, Etudes}
# 6                {Conseil, Juridique, Audit, Fiscal}
# 7                {Conseil, Juridique, Audit, Fiscal}
# 25  {Communication, Commercial, Marketing, Création}
# 23  {Communication, Commercial, Marketing, Création}
# 24                        {Communication, Marketing}
# 26                        {Communication, Marketing}
# 27                {Qualité, Sécurité, Environnement}
# 28                {Qualité, Sécurité, Environnement}
# 29                {Qualité, Sécurité, Environnement}
# 31     {Hôtellerie, Loisirs, Tourisme, Restauration}
# 32     {Hôtellerie, Loisirs, Tourisme, Restauration}
# 33     {Hôtellerie, Loisirs, Tourisme, Restauration}
# 34             {Achat, Logistique, Stock, Transport}
# 35             {Achat, Logistique, Stock, Transport}
# 36             {Achat, Logistique, Stock, Transport}
#
#                                                                                union  \
# 21                                             {Design, Médias Numériques, Création}
# 22                                             {Design, Médias Numériques, Création}
# 10     {Production, Maintenance, Méthode, Industrie, Electrique et Électrotechnique}
# 11     {Production, Maintenance, Méthode, Industrie, Electrique et Électrotechnique}
# 18  {Systèmes d'Information, Informatique, Analyse et Science des Données, Internet}
# 19  {Systèmes d'Information, Informatique, Analyse et Science des Données, Internet}
# 40                                {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 38                                {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 39                                {Projet, Ingénierie, R&D, Bureau d'Études, Etudes}
# 6                                                {Fiscal, Juridique, Audit, Conseil}
# 7                                                {Fiscal, Juridique, Audit, Conseil}
# 25                              {Communication, RP, Commercial, Marketing, Création}
# 23                              {Communication, RP, Commercial, Marketing, Création}
# 24                                                    {Communication, RP, Marketing}
# 26                                                    {Communication, RP, Marketing}
# 27                                                {Qualité, Sécurité, Environnement}
# 28                                                {Qualité, Sécurité, Environnement}
# 29                                                {Qualité, Sécurité, Environnement}
# 31                                     {Hôtellerie, Restauration, Loisirs, Tourisme}
# 32                                     {Hôtellerie, Restauration, Loisirs, Tourisme}
# 33                                     {Hôtellerie, Restauration, Loisirs, Tourisme}
# 34                                  {Stock, Achat, Transport, Emballage, Logistique}
# 35                                  {Stock, Achat, Transport, Emballage, Logistique}
# 36                                  {Stock, Achat, Transport, Emballage, Logistique}
#
#                                                                          union_str  \
# 21                                             Création, Design, Médias Numériques
# 22                                             Création, Design, Médias Numériques
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 11     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 18  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 19  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 40                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 38                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 39                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 6                                                Audit, Conseil, Fiscal, Juridique
# 7                                                Audit, Conseil, Fiscal, Juridique
# 25                              Commercial, Communication, Création, Marketing, RP
# 23                              Commercial, Communication, Création, Marketing, RP
# 24                                                    Communication, Marketing, RP
# 26                                                    Communication, Marketing, RP
# 27                                                Environnement, Qualité, Sécurité
# 28                                                Environnement, Qualité, Sécurité
# 29                                                Environnement, Qualité, Sécurité
# 31                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 32                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 33                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 34                                  Achat, Emballage, Logistique, Stock, Transport
# 35                                  Achat, Emballage, Logistique, Stock, Transport
# 36                                  Achat, Emballage, Logistique, Stock, Transport
#
#     replace_emploi_partner  replace_emploitic
# 21                   False               True
# 22                   False               True
# 10                    True               True
# 11                    True               True
# 18                    True               True
# 19                    True               True
# 40                    True               True
# 38                    True               True
# 39                    True               True
# 6                     True              False
# 7                     True              False
# 25                    True               True
# 23                    True               True
# 24                   False               True
# 26                   False               True
# 27                   False              False
# 28                   False              False
# 29                   False              False
# 31                    True              False
# 32                    True              False
# 33                    True              False
# 34                    True               True
# 35                    True               True
# 36                    True               True

# %%
# the replacements to be used in each source data transformation step
df_values_to_replace_ep = merged_filtered.loc[
    merged_filtered["replace_emploi_partner"], ["emploi_partner", "union_str"]
].drop_duplicates()
df_values_to_replace_em = merged_filtered.loc[
    merged_filtered["replace_emploitic"], ["emploitic", "union_str"]
].drop_duplicates()
display(df_values_to_replace_ep)
display(df_values_to_replace_em)
# Out:
#                                                           emploi_partner  \
# 10    Industrie, Electrique et Électrotechnique, Production, Maintenance
# 18  Informatique, Systèmes d'Information, Analyse et Science des Données
# 40                              Ingénierie, Bureau d'Études, Projet, R&D
# 6                                                      Juridique, Fiscal
# 25                                          Marketing, Communication, RP
# 31                                    Tourisme, Hôtellerie, Restauration
# 34                               Transport, Achat, Logistique, Emballage
#
#                                                                          union_str
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 18  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 40                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 6                                                Audit, Conseil, Fiscal, Juridique
# 25                              Commercial, Communication, Création, Marketing, RP
# 31                                     Hôtellerie, Loisirs, Restauration, Tourisme
# 34                                  Achat, Emballage, Logistique, Stock, Transport
#                                           emploitic  \
# 21                                 Création, Design
# 10                   Production, Méthode, Industrie
# 18   Informatique, Systèmes d'Information, Internet
# 40                  Ingénierie, Etudes, Projet, R&D
# 25  Commercial, Marketing, Communication & Création
# 24                         Marketing, Communication
# 34              Logistique, Achat, Stock, Transport
#
#                                                                          union_str
# 21                                             Création, Design, Médias Numériques
# 10     Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production
# 18  Analyse et Science des Données, Informatique, Internet, Systèmes d'Information
# 40                                Bureau d'Études, Etudes, Ingénierie, Projet, R&D
# 25                              Commercial, Communication, Création, Marketing, RP
# 24                                                    Communication, Marketing, RP
# 34                                  Achat, Emballage, Logistique, Stock, Transport

# %%
values_to_replace_ep = dict(zip(
    df_values_to_replace_ep["emploi_partner"], df_values_to_replace_ep["union_str"]
))

values_to_replace_em = dict(zip(
    df_values_to_replace_em["emploitic"], df_values_to_replace_em["union_str"]
))
display(values_to_replace_ep)
display(values_to_replace_em)
# Out:
# {'Industrie, Electrique et Électrotechnique, Production, Maintenance': 'Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production',
#  "Informatique, Systèmes d'Information, Analyse et Science des Données": "Analyse et Science des Données, Informatique, Internet, Systèmes d'Information",
#  "Ingénierie, Bureau d'Études, Projet, R&D": "Bureau d'Études, Etudes, Ingénierie, Projet, R&D",
#  'Juridique, Fiscal': 'Audit, Conseil, Fiscal, Juridique',
#  'Marketing, Communication, RP': 'Commercial, Communication, Création, Marketing, RP',
#  'Tourisme, Hôtellerie, Restauration': 'Hôtellerie, Loisirs, Restauration, Tourisme',
#  'Transport, Achat, Logistique, Emballage': 'Achat, Emballage, Logistique, Stock, Transport'}
# {'Création, Design': 'Création, Design, Médias Numériques',
#  'Production, Méthode, Industrie': 'Electrique et Électrotechnique, Industrie, Maintenance, Méthode, Production',
#  "Informatique, Systèmes d'Information, Internet": "Analyse et Science des Données, Informatique, Internet, Systèmes d'Information",
#  'Ingénierie, Etudes, Projet, R&D': "Bureau d'Études, Etudes, Ingénierie, Projet, R&D",
#  'Commercial, Marketing, Communication & Création': 'Commercial, Communication, Création, Marketing, RP',
#  'Marketing, Communication': 'Communication, Marketing, RP',
#  'Logistique, Achat, Stock, Transport': 'Achat, Emballage, Logistique, Stock, Transport'}

# %%
# inspect the remaining rows and look for matchable values
# that were missed due to subtle changes (e.g Réseaux vs Réseau)
unmatched_ep_df = ep_df[
    ~ep_df["emploi_partner"].isin(values_to_replace_ep.keys())
]
unmatched_em_df = em_df[
    ~em_df["emploitic"].isin(values_to_replace_em.keys())
]
merged_unmatched = pd.merge(
    unmatched_ep_df,
    unmatched_em_df,
    left_on="emploi_partner",
    right_on="emploitic",
    how="outer"
)
merged_unmatched[["emploi_partner", "emploitic"]]
# Out:
#                                             emploi_partner  \
# 0              Accueil, Administration - Services Généraux
# 1                                                      NaN
# 2                                                      NaN
# 3                                          Armées, Défense
# 4                                                      NaN
# 5                         Audit, Gestion, Finances, Compta
# 6                                                      NaN
# 7                                                   Autres
# 8                                Banque, Bourse, Assurance
# 9                                     Batiment, Équipement
# 10                                                     NaN
# 11          Chauffeur, Agent d'Entretien, Agent Polyvalent
# 12                                        Chimie, Biologie
# 13                             Collectivité Secteur Public
# 14                           Commerce, Distribution, Vente
# 15                                                     NaN
# 16                                                     NaN
# 17            Contact Client, SAV, Centre d'Appel, Enquête
# 18                           Création, Culture, Spectacles
# 19                     Création, Design, Médias Numériques
# 20                                                     NaN
# 21  Direction, Entrepreneuriat, Cadres Dirigeants, Experts
# 22                 Edition, Imprimerie, Presse, Traduction
# 23                                                     NaN
# 24                        Formation, Enseignement, Langues
# 25                                                     NaN
# 26            Immobilier, Architecture, Urbanisme, Paysage
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# 30                                                     NaN
# 31                                                     NaN
# 32                                              Management
# 33                                      Mode, Luxe, Beauté
# 34                                                     NaN
# 35                       Métiers Manuels et de l'Artisanat
# 36                                                     NaN
# 37                        Métiers de l'Agriculture, Nature
# 38                                                     NaN
# 39                    Ouvriés, Maneouvre, Manutentionnaire
# 40                                          Petite Enfance
# 41                        Qualité, Sécurité, Environnement
# 42                                                     NaN
# 43                                                     NaN
# 44                                 Ressources Humaines-Grh
# 45                           Santé Hopital, Pharmaceutique
# 46                                                     NaN
# 47                                                     NaN
# 48                                                Services
# 49           Social, Médico-Social, Services À la Personne
# 50                                                   Sport
# 51                                                  Sports
# 52                                                     NaN
# 53                    Télécommunications, Systèmes, Réseau
# 54                                                     NaN
#
#                                             emploitic
# 0                                                 NaN
# 1   Administration, Finance, Comptabilité & Juridique
# 2                     Administration, Moyens Généraux
# 3                                                 NaN
# 4                             Assistanat, Secrétariat
# 5                                                 NaN
# 6                                               Autre
# 7                                              Autres
# 8                                                 NaN
# 9                                                 NaN
# 10                Chantier, Métiers BTP, Architecture
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15    Commercial, Technico Commercial, Service Client
# 16                              Comptabilité, Finance
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20              Direction Générale, Direction d'Unité
# 21                                                NaN
# 22                                                NaN
# 23                            Education, Enseignement
# 24                                                NaN
# 25        Hôtellerie, Tourisme, Restauration, Loisirs
# 26                                                NaN
# 27          Informatique, Télécommunication & Réseaux
# 28                Ingénierie, Industrie, Construction
# 29                    Journalisme, Médias, Traduction
# 30                  Juridique, Fiscal, Audit, Conseil
# 31                             Maintenance, Entretien
# 32                                                NaN
# 33                                                NaN
# 34                       Métiers Banque et Assurances
# 35                                                NaN
# 36                           Métiers de l'Agriculture
# 37                                                NaN
# 38                      Ouvriers Qualifiés, Chauffeur
# 39                                                NaN
# 40                                                NaN
# 41                   Qualité, Sécurité, Environnement
# 42                           RH, Personnel, Formation
# 43             Responsable Commercial, Grands Comptes
# 44                                                NaN
# 45                                                NaN
# 46    Santé, Médical, Pharmaceutique, Délégué Médical
# 47                          Santé, Médical, Pharmacie
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                         Télécommunication, Réseaux
# 53                                                NaN
# 54                       Vente, Télévente, Assistanat
